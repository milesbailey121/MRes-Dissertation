# %%
import numpy as np
from cellpose import models, io
from cellpose.io import imread
import os
import tifffile
from matplotlib import pyplot as plt

# %%
io.logger_setup()

#Depending on 
# model = models.CellposeModel(pretrained_model=".\pretrained-model",gpu=True)
model = models.Cellpose(model_type="cyto3",gpu=True)

# list of files
root_dir = r"D:\data\ecad_nuc_split"
# Out:
# creating new log file
# 2025-03-12 14:12:10,700 [INFO] WRITING LOG OUTPUT TO C:\Users\woodl\.cellpose\run.log
# 2025-03-12 14:12:10,962 [INFO]
# cellpose version: 	3.1.1.1
# platform:       	win32
# python version: 	3.12.8
# torch version:  	2.6.0+cpu
# 2025-03-12 14:12:13,529 [INFO] Neither TORCH CUDA nor MPS version not installed/working.
# 2025-03-12 14:12:13,549 [INFO] >>>> using CPU
# 2025-03-12 14:12:13,550 [INFO] >>>> using CPU
# 2025-03-12 14:12:13,903 [INFO] >> cyto3 << model set to be used
# 2025-03-12 14:12:17,523 [INFO] >>>> loading model C:\Users\woodl\.cellpose\models\cyto3
# 2025-03-12 14:12:20,579 [INFO] >>>> model diam_mean =  30.000 (ROIs rescaled to this size during training)

# %%
# Define channels to run segmentation on(Nuclear and E-cadherin)
channels = [[2, 1]]

# Create the root output directory if it doesn't exist
output_root = r"D:\data\masks"
if not os.path.exists(output_root):
    os.makedirs(output_root)

# Traverse the directory tree
for dirpath, dirnames, filenames in os.walk(root_dir):
    for filename in filenames:
        if filename.endswith(('.tif', '.tiff')):  # Add other image extensions if necessary
            image_path = os.path.join(dirpath, filename)
            
            # Read the image
            image = imread(image_path)
            
            # Evaluate the model on the image
            # masks, flows, styles = model.eval([image], diameter=None, channels=channels)
            masks, flows, styles,diams = model.eval([image], diameter=None, channels=channels)
            
            # Create the corresponding output path
            relative_path = os.path.relpath(image_path, root_dir)
            output_path = os.path.join(output_root, relative_path)
            
            # Create necessary directories
            output_dir = os.path.dirname(output_path)
            if not os.path.exists(output_dir):
                os.makedirs(output_dir)
            
            # Save the mask image
            tifffile.imwrite(output_path, masks[0])

print("Processing and saving completed.")
# Out:
# 2025-03-12 12:34:24,290 [INFO] channels set to [[2, 1]]
# 2025-03-12 12:34:24,290 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# d:\miniconda\envs\image-python\Lib\site-packages\cellpose\transforms.py:600: UserWarning: 'chan to seg' to seg has value range of ZERO
#   warnings.warn("'chan to seg' to seg has value range of ZERO")
# d:\miniconda\envs\image-python\Lib\site-packages\cellpose\transforms.py:602: UserWarning: 'chan2 (opt)' has value range of ZERO, can instead set chan2 to 0
#   warnings.warn(
# 2025-03-12 12:34:31,704 [INFO] No cell pixels found.
# 2025-03-12 12:34:31,809 [INFO] estimated cell diameter(s) in 7.52 sec
# 2025-03-12 12:34:31,811 [INFO] >>> diameter(s) =
# 2025-03-12 12:34:31,812 [INFO] [30.00, ]
# 2025-03-12 12:34:31,813 [INFO] ~~~ FINDING MASKS ~~~
# d:\miniconda\envs\image-python\Lib\site-packages\numpy\_core\fromnumeric.py:3596: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# d:\miniconda\envs\image-python\Lib\site-packages\numpy\_core\_methods.py:138: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-03-12 12:34:33,213 [INFO] No cell pixels found.
# 2025-03-12 12:34:33,230 [INFO] >>>> TOTAL TIME 8.94 sec
# 2025-03-12 12:34:33,243 [INFO] channels set to [[2, 1]]
# 2025-03-12 12:34:33,244 [INFO] ~~~ ESTIMATING CELL DIAMETER(S) ~~~
# 2025-03-12 12:34:42,702 [INFO] estimated cell diameter(s) in 9.46 sec
# 2025-03-12 12:34:42,703 [INFO] >>> diameter(s) =
# 2025-03-12 12:34:42,703 [INFO] [9.10, ]
# 2025-03-12 12:34:42,704 [INFO] ~~~ FINDING MASKS ~~~
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 20
#      16 image = imread(image_path)
#      18 # Evaluate the model on the image
#      19 # masks, flows, styles = model.eval([image], diameter=None, channels=channels)
# ---> 20 masks, flows, styles,diams = model.eval([image], diameter=None, channels=channels)
#      22 # Create the corresponding output path
#      23 relative_path = os.path.relpath(image_path, root_dir)
#
# File d:\miniconda\envs\image-python\Lib\site-packages\cellpose\models.py:207, in Cellpose.eval(self, x, batch_size, channels, channel_axis, invert, normalize, diameter, do_3D, **kwargs)
#     204     diams = diameter
#     206 models_logger.info("~~~ FINDING MASKS ~~~")
# --> 207 masks, flows, styles = self.cp.eval(x, channels=channels,
#     208                                     channel_axis=channel_axis,
#     209                                     batch_size=batch_size, normalize=normalize,
#     210                                     invert=invert, diameter=diams, do_3D=do_3D,
#     211                                     **kwargs)
#     212 models_logger.info(">>>> TOTAL TIME %0.2f sec" % (time.time() - tic0))
#     214 return masks, flows, styles, diams
#
# File d:\miniconda\envs\image-python\Lib\site-packages\cellpose\models.py:452, in CellposeModel.eval(self, x, batch_size, resample, channels, channel_axis, z_axis, normalize, invert, rescale, diameter, flow_threshold, cellprob_threshold, do_3D, anisotropy, flow3D_smooth, stitch_threshold, min_size, max_size_fraction, niter, augment, tile_overlap, bsize, interp, compute_masks, progress)
#     450 for i in iterator:
#     451     tic = time.time()
# --> 452     maski, flowi, stylei = self.eval(
#     453         x[i], batch_size=batch_size,
#     454         channels=channels[i] if channels is not None and
#     455         ((len(channels) == len(x) and
#     456           (isinstance(channels[i], list) or
#     457            isinstance(channels[i], np.ndarray)) and len(channels[i]) == 2))
#     458         else channels, channel_axis=channel_axis, z_axis=z_axis,
#     459         normalize=normalize, invert=invert,
#     460         rescale=rescale[i] if isinstance(rescale, list) or
#     461         isinstance(rescale, np.ndarray) else rescale,
#     462         diameter=diameter[i] if isinstance(diameter, list) or
#     463         isinstance(diameter, np.ndarray) else diameter, do_3D=do_3D,
#     464         anisotropy=anisotropy, augment=augment,
#     465         tile_overlap=tile_overlap, bsize=bsize, resample=resample,
#     466         interp=interp, flow_threshold=flow_threshold,
#     467         cellprob_threshold=cellprob_threshold, compute_masks=compute_masks,
#     468         min_size=min_size, max_size_fraction=max_size_fraction,
#     469         stitch_threshold=stitch_threshold, flow3D_smooth=flow3D_smooth,
#     470         progress=progress, niter=niter)
#     471     masks.append(maski)
#     472     flows.append(flowi)
#
# File d:\miniconda\envs\image-python\Lib\site-packages\cellpose\models.py:518, in CellposeModel.eval(self, x, batch_size, resample, channels, channel_axis, z_axis, normalize, invert, rescale, diameter, flow_threshold, cellprob_threshold, do_3D, anisotropy, flow3D_smooth, stitch_threshold, min_size, max_size_fraction, niter, augment, tile_overlap, bsize, interp, compute_masks, progress)
#     515 if do_normalization:
#     516     x = transforms.normalize_img(x, **normalize_params)
# --> 518 dP, cellprob, styles = self._run_net(
#     519     x, rescale=rescale, augment=augment,
#     520     batch_size=batch_size, tile_overlap=tile_overlap, bsize=bsize,
#     521     resample=resample, do_3D=do_3D, anisotropy=anisotropy)
#     523 if do_3D:
#     524     if flow3D_smooth > 0:
#
# File d:\miniconda\envs\image-python\Lib\site-packages\cellpose\models.py:577, in CellposeModel._run_net(self, x, rescale, resample, augment, batch_size, tile_overlap, bsize, anisotropy, do_3D)
#     575     dP = yf[..., :-1].transpose((3, 0, 1, 2))
#     576 else:
# --> 577     yf, styles = run_net(self.net, x, bsize=bsize, augment=augment,
#     578                         batch_size=batch_size,
#     579                         tile_overlap=tile_overlap,
#     580                         rsz=rescale if rescale!=1.0 else None)
#     581     if resample:
#     582         if rescale != 1.0:
#
# File d:\miniconda\envs\image-python\Lib\site-packages\cellpose\core.py:264, in run_net(net, imgi, batch_size, augment, tile_overlap, bsize, rsz)
#     262 for j in range(0, IMGa.shape[0], batch_size):
#     263     bslc = slice(j, min(j + batch_size, IMGa.shape[0]))
# --> 264     ya[bslc], stylea[bslc] = _forward(net, IMGa[bslc])
#     265 for i, b in enumerate(inds):
#     266     y = ya[i * ntiles : (i + 1) * ntiles]
#
# File d:\miniconda\envs\image-python\Lib\site-packages\cellpose\core.py:190, in _forward(net, x)
#     188     net = mkldnn_utils.to_mkldnn(net)
#     189 with torch.no_grad():
# --> 190     y, style = net(X)[:2]
#     191 del X
#     192 y = _from_device(y)
#
# File d:\miniconda\envs\image-python\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File d:\miniconda\envs\image-python\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\miniconda\envs\image-python\Lib\site-packages\cellpose\resnet_torch.py:246, in CPnet.forward(self, data)
#     244 if not self.style_on:
#     245     style = style * 0
# --> 246 T1 = self.upsample(style, T0, self.mkldnn)
#     247 T1 = self.output(T1)
#     248 if self.mkldnn:
#
# File d:\miniconda\envs\image-python\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File d:\miniconda\envs\image-python\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\miniconda\envs\image-python\Lib\site-packages\cellpose\resnet_torch.py:158, in upsample.forward(self, style, xd, mkldnn)
#     156     else:
#     157         x = self.upsampling(x)
# --> 158     x = self.up[n](x, xd[n], style, mkldnn=mkldnn)
#     159 return x
#
# File d:\miniconda\envs\image-python\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File d:\miniconda\envs\image-python\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\miniconda\envs\image-python\Lib\site-packages\cellpose\resnet_torch.py:121, in resup.forward(self, x, y, style, mkldnn)
#     120 def forward(self, x, y, style, mkldnn=False):
# --> 121     x = self.proj(x) + self.conv[1](style, self.conv[0](x), y=y, mkldnn=mkldnn)
#     122     x = x + self.conv[3](style, self.conv[2](style, x, mkldnn=mkldnn),
#     123                          mkldnn=mkldnn)
#     124     return x
#
# File d:\miniconda\envs\image-python\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File d:\miniconda\envs\image-python\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\miniconda\envs\image-python\Lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File d:\miniconda\envs\image-python\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File d:\miniconda\envs\image-python\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# KeyboardInterrupt:
